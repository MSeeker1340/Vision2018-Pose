# %%
import numpy as np
import matplotlib.pyplot as pyplot
from skimage.transform import resize

# %%
def plot_result(y, f):
    rshape = y.shape
    ishape = (224, 224, 3)
    result = np.zeros(ishape)
    # scale = (ishape[0]/rshape[0], ishape[1]/rshape[1])
    result[:,:,0] = resize(y[:,:,f].transpose(), (224, 224), mode='reflect', anti_aliasing=True)
    return result
    #pyplot.imshow(result)

# %%
def plot_on_img(x, y, f):
    sigma = 0.05
    result = plot_result(y, f)
    img = np.zeros(x.shape)
    img[:,:,:] = x
    for i in range(result.shape[0]):
        for j in range(result.shape[1]):
            if result[i, j, 0] >= 0.5:
                img[i, j, 0] = result[i, j, 0]
                img[i, j, ]
    pyplot.imshow(img)

# %%
X = np.load("../X_train.npy")
X1 = np.load("./X.npy")

# %%
Y = np.load("../Y_train.npy")
Y1 = np.load("./Y.npy")

# %%
plot_result(Y[2], 0)
# Out:
# array([[[0.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#         [0.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#         [0.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#         ...,
#         [4.78003148e-036, 0.00000000e+000, 0.00000000e+000],
#         [4.04464204e-036, 0.00000000e+000, 0.00000000e+000],
#         [3.30925259e-036, 0.00000000e+000, 0.00000000e+000]],
#
#        [[0.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#         [0.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#         [0.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#         ...,
#         [3.42024500e-036, 0.00000000e+000, 0.00000000e+000],
#         [2.89405347e-036, 0.00000000e+000, 0.00000000e+000],
#         [2.36786194e-036, 0.00000000e+000, 0.00000000e+000]],
#
#        [[0.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#         [0.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#         [0.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#         ...,
#         [2.06045852e-036, 0.00000000e+000, 0.00000000e+000],
#         [1.74346490e-036, 0.00000000e+000, 0.00000000e+000],
#         [1.42647129e-036, 0.00000000e+000, 0.00000000e+000]],
#
#        ...,
#
#        [[0.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#         [0.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#         [0.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#         ...,
#         [1.03087813e-250, 0.00000000e+000, 0.00000000e+000],
#         [8.72281497e-251, 0.00000000e+000, 0.00000000e+000],
#         [7.13684864e-251, 0.00000000e+000, 0.00000000e+000]],
#
#        [[0.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#         [0.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#         [0.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#         ...,
#         [1.71813022e-250, 0.00000000e+000, 0.00000000e+000],
#         [1.45380250e-250, 0.00000000e+000, 0.00000000e+000],
#         [1.18947477e-250, 0.00000000e+000, 0.00000000e+000]],
#
#        [[0.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#         [0.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#         [0.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#         ...,
#         [2.40538230e-250, 0.00000000e+000, 0.00000000e+000],
#         [2.03532349e-250, 0.00000000e+000, 0.00000000e+000],
#         [1.66526468e-250, 0.00000000e+000, 0.00000000e+000]]])

# %%
pyplot.imshow(X1[1])

# %%
plot_on_img(X[1], Y[1], 0)
